# %% [markdown]
# # Business plan
# ## By Michael Moxey

# %% [markdown]
# Using the Foursquare API I will find out what borough you are most likely in depending on which store you are in. I will create a decision tree that will go through the boroughs comparing the likelyhood of stores.

# %% [markdown]
# ## Data

# %% [markdown]
# The data I will use is the 2014 New york city Neighborhood Names from NYU Spatial Data Repository and the foursquare API.

# %%
import numpy as np 
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium
import json

# %%
with open('C:\\Users\\micha\\Desktop\\Jupyter notebook\\rows.json') as json_data:
    newyork_data = json.load(json_data)

# %%
newyork_data
# Out:
# {'meta': {'view': {'id': 'xyye-rtrs',
#    'name': 'NHoodNameCentroids',
#    'assetType': 'invalid_datatype',
#    'averageRating': 0,
#    'createdAt': 1365528012,
#    'displayType': 'geoRows',
#    'downloadCount': 13461,
#    'hideFromCatalog': True,
#    'hideFromDataJson': True,
#    'indexUpdatedAt': 1537209301,
#    'newBackend': True,
#    'numberOfComments': 0,
#    'oid': 15699813,
#    'provenance': 'community',
#    'publicationAppendEnabled': False,
#    'publicationGroup': 6258719,
#    'publicationStage': 'published',
#    'tableId': 6258719,
#    'totalTimesRated': 0,
#    'viewCount': 56,
#    'viewLastModified': 1536598173,
#    'viewType': 'tabular',
#    'approvals': [{'reviewableUid': '99bc-9p23',
#      'reviewedAt': 1365528013,
#      'reviewedAutomatically': True,
#      'state': 'approved',
#      'submissionId': 1065643,
#      'submissionObject': 'public_audience_request',
#      'submissionOutcome': 'change_audience',
#      'submittedAt': 1365528013,
#      'workflowId': 2285,
#      'submissionDetails': {'permissionType': 'READ'},
#      'submissionOutcomeApplication': {'failureCount': 0, 'status': 'success'},
#      'submitter': {'id': '5fuc-pqz2', 'displayName': 'NYC OpenData'}}],
#    'childViews': [''],
#    'columns': [{'id': -1,
#      'name': 'sid',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':sid',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'id',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':id',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'position',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':position',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': 234833271,
#      'name': 'the_geom',
#      'dataTypeName': 'point',
#      'fieldName': 'the_geom',
#      'position': 1,
#      'renderTypeName': 'point',
#      'tableColumnId': 33432350,
#      'format': {}},
#     {'id': 234833274,
#      'name': 'OBJECTID',
#      'dataTypeName': 'number',
#      'fieldName': 'objectid',
#      'position': 2,
#      'renderTypeName': 'number',
#      'tableColumnId': 33432353,
#      'format': {}},
#     {'id': 234833278,
#      'name': 'Name',
#      'dataTypeName': 'text',
#      'fieldName': 'name',
#      'position': 3,
#      'renderTypeName': 'text',
#      'tableColumnId': 33432357,
#      'format': {}},
#     {'id': 234833281,
#      'name': 'Stacked',
#      'dataTypeName': 'number',
#      'fieldName': 'stacked',
#      'position': 4,
#      'renderTypeName': 'number',
#      'tableColumnId': 33432360,
#      'format': {}},
#     {'id': 234833284,
#      'name': 'AnnoLine1',
#      'dataTypeName': 'text',
#      'fieldName': 'annoline1',
#      'position': 5,
#      'renderTypeName': 'text',
#      'tableColumnId': 33432363,
#      'format': {}},
#     {'id': 234833289,
#      'name': 'AnnoLine2',
#      'dataTypeName': 'text',
#      'fieldName': 'annoline2',
#      'position': 6,
#      'renderTypeName': 'text',
#      'tableColumnId': 33432368,
#      'format': {}},
#     {'id': 234833295,
#      'name': 'AnnoLine3',
#      'dataTypeName': 'text',
#      'fieldName': 'annoline3',
#      'position': 7,
#      'renderTypeName': 'text',
#      'tableColumnId': 33432374,
#      'format': {}},
#     {'id': 234833300,
#      'name': 'AnnoAngle',
#      'dataTypeName': 'number',
#      'fieldName': 'annoangle',
#      'position': 8,
#      'renderTypeName': 'number',
#      'tableColumnId': 33432379,
#      'format': {}},
#     {'id': 234833304,
#      'name': 'Borough',
#      'dataTypeName': 'text',
#      'fieldName': 'borough',
#      'position': 9,
#      'renderTypeName': 'text',
#      'tableColumnId': 33432383,
#      'format': {}}],
#    'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#    'metadata': {'geo': {'parentUid': '99bc-9p23', 'isNbe': True},
#     'custom_fields': {'Update': {'Date Made Public': '6/28/2013'}}},
#    'owner': {'id': 'qy85-itiy',
#     'displayName': 'gneuhaus',
#     'profileImageUrlLarge': '/api/users/qy85-itiy/profile_images/LARGE',
#     'profileImageUrlMedium': '/api/users/qy85-itiy/profile_images/THUMB',
#     'profileImageUrlSmall': '/api/users/qy85-itiy/profile_images/TINY',
#     'screenName': 'gneuhaus',
#     'type': 'interactive'},
#    'query': {},
#    'rights': ['read'],
#    'tableAuthor': {'id': 'qy85-itiy',
#     'displayName': 'gneuhaus',
#     'profileImageUrlLarge': '/api/users/qy85-itiy/profile_images/LARGE',
#     'profileImageUrlMedium': '/api/users/qy85-itiy/profile_images/THUMB',
#     'profileImageUrlSmall': '/api/users/qy85-itiy/profile_images/TINY',
#     'screenName': 'gneuhaus',
#     'type': 'interactive'},
#    'flags': ['default', 'restorable', 'restorePossibleForType']}},
#  'data': [['row-7q9n-adg4_xvee',
#    '00000000-0000-0000-BC1E-0359B8CD43D9',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8472005205491 40.89470517661004)',
#    '1',
#    'Wakefield',
#    '1',
#    'Wakefield',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-s456-uyfi_n9s7',
#    '00000000-0000-0000-20BE-C45ADF984BA3',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.82993910812405 40.87429419303015)',
#    '2',
#    'Co-op City',
#    '2',
#    'Co-op',
#    'City',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-u3k6_dcav_ttga',
#    '00000000-0000-0000-087B-F1F6EE4D2211',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.82780644716419 40.88755567735082)',
#    '3',
#    'Eastchester',
#    '1',
#    'Eastchester',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-j32v_q7hh_s8s2',
#    '00000000-0000-0000-B14B-8407E1F6A6A4',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90564259591689 40.895437426903875)',
#    '4',
#    'Fieldston',
#    '1',
#    'Fieldston',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-ieni.97rx~mxs8',
#    '00000000-0000-0000-B4BB-60991CBABE96',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91258546108577 40.89083449389134)',
#    '5',
#    'Riverdale',
#    '1',
#    'Riverdale',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-trix_8ybz-8h9e',
#    '00000000-0000-0000-2A91-72A5ADB3E3FA',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90281798724611 40.88168737120525)',
#    '6',
#    'Kingsbridge',
#    '1',
#    'Kingsbridge',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-cx7g_5dfe_2bg5',
#    '00000000-0000-0000-7D01-5FA4F836CD94',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91065965862988 40.87655077879968)',
#    '7',
#    'Marble Hill',
#    '2',
#    'Marble',
#    'Hill',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-jidv_6gem.g9ep',
#    '00000000-0000-0000-E3D2-930963CDFC2D',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.86731496814183 40.898272612138086)',
#    '8',
#    'Woodlawn',
#    '1',
#    'Woodlawn',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-kzfd~mr7v~4zcw',
#    '00000000-0000-0000-2EB0-0DB26CF75219',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.87939073956817 40.877224155994504)',
#    '9',
#    'Norwood',
#    '1',
#    'Norwood',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-hkgb-m2q7.48b5',
#    '00000000-0000-0000-F64D-8CDEEDE06DA2',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.85744642974214 40.88103887819214)',
#    '10',
#    'Williamsbridge',
#    '1',
#    'Williamsbridge',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-a84d.xkfd-cxys',
#    '00000000-0000-0000-9424-AA7497071FBF',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.83579759808124 40.86685810725274)',
#    '11',
#    'Baychester',
#    '1',
#    'Baychester',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-7w6g~3ipa-ntmv',
#    '00000000-0000-0000-C8BC-D4CBEA02E066',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.85475564018006 40.85741349808869)',
#    '12',
#    'Pelham Parkway',
#    '1',
#    'Pelham Parkway',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-ybcg-5hav.64ta',
#    '00000000-0000-0000-964A-EB69707567B1',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.7864884526742 40.84724670491817)',
#    '13',
#    'City Island',
#    '2',
#    'City',
#    'Island',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-tqwr-4vbf_j2qi',
#    '00000000-0000-0000-57F1-7DE91B6FE6AB',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.88551218419137 40.87018516497537)',
#    '14',
#    'Bedford Park',
#    '2',
#    'Bedford',
#    'Park',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-xnux-fdxv_rvip',
#    '00000000-0000-0000-7C9A-9862398B7C95',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91041596191317 40.85572707719668)',
#    '15',
#    'University Heights',
#    '2',
#    'University',
#    'Heights',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-yhrs-kkhi~q78a',
#    '00000000-0000-0000-BF50-7A2BA13FA100',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91967159119572 40.84789792606274)',
#    '16',
#    'Morris Heights',
#    '2',
#    'Morris',
#    'Heights',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-62pg~r5ma.sh5e',
#    '00000000-0000-0000-FB55-7892486B5456',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8964265598163 40.86099679638657)',
#    '17',
#    'Fordham',
#    '1',
#    'Fordham',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-a4tz.buhs_paan',
#    '00000000-0000-0000-90E4-98FE09EAC9F1',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.88735617532345 40.84269615786057)',
#    '18',
#    'East Tremont',
#    '2',
#    'East',
#    'Tremont',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-wzb6.d3k9-bjht',
#    '00000000-0000-0000-890B-958F1C01BFFB',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.87774474910552 40.83947505672657)',
#    '19',
#    'West Farms',
#    '2',
#    'West',
#    'Farms',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-rby5-6zdr~3f3t',
#    '00000000-0000-0000-7C91-56C36EC9BAB1',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.92610209358138 40.8366230107061)',
#    '20',
#    'High  Bridge',
#    '2',
#    'High',
#    'Bridge',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-phxy-8j26_rzxv',
#    '00000000-0000-0000-B1F5-0A6BB3825F99',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90942160757443 40.81975437059498)',
#    '21',
#    'Melrose',
#    '1',
#    'Melrose',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-x6ep-ksh2-rajk',
#    '00000000-0000-0000-163C-889A57F28FE7',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91609987487583 40.80623874935181)',
#    '22',
#    'Mott Haven',
#    '1',
#    'Mott Haven',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-jmeb_yni6_tgza',
#    '00000000-0000-0000-B8F4-1CB533BC859B',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91322139386142 40.80166362775625)',
#    '23',
#    'Port Morris',
#    '2',
#    'Port',
#    'Morris',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-xyhh~hsjf_i343',
#    '00000000-0000-0000-0DBF-20D2FFCAA41C',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.89578820094466 40.815099045458254)',
#    '24',
#    'Longwood',
#    '1',
#    'Longwood',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-j88c~dzwr-mhd8',
#    '00000000-0000-0000-952B-7733CFD620F6',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.88331505955298 40.809729879387135)',
#    '25',
#    'Hunts Point',
#    '2',
#    'Hunts',
#    'Point',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-k952-q9rf.khmu',
#    '00000000-0000-0000-E4A0-3B0E18F71CF2',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90150648943066 40.82359198585537)',
#    '26',
#    'Morrisania',
#    '1',
#    'Morrisania',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-snip_qn39_94rm',
#    '00000000-0000-0000-928B-E5B450DC7D91',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.86574609554933 40.82101219791406)',
#    '27',
#    'Soundview',
#    '1',
#    'Soundview',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-scck~cprs~mjwb',
#    '00000000-0000-0000-9612-ACB1F11764E8',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.85414416189273 40.806551120035934)',
#    '28',
#    'Clason Point',
#    '2',
#    'Clason',
#    'Point',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-3gpg.ur58.78gc',
#    '00000000-0000-0000-B284-EC168D62891A',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8163500215845 40.815109258040096)',
#    '29',
#    'Throgs Neck',
#    '1',
#    'Throgs Neck',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-kwrf_9nck-fhwf',
#    '00000000-0000-0000-8565-F5DE7253B87D',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.82409926753857 40.84424593694742)',
#    '30',
#    'Country Club',
#    '2',
#    'Country',
#    'Club',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-2rnr-d4d3-5q2h',
#    '00000000-0000-0000-A287-7D48CDDC9CF1',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8560031053579 40.83793782226733)',
#    '31',
#    'Parkchester',
#    '1',
#    'Parkchester',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-tir7~hn63_8hcq',
#    '00000000-0000-0000-1132-7C1F852A5E9B',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8421940760445 40.840619496432744)',
#    '32',
#    'Westchester Square',
#    '2',
#    'Westchester',
#    'Square',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-ugez.ckfd~jawe',
#    '00000000-0000-0000-23F8-2C168CF313A7',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.86629918075617 40.84360847124722)',
#    '33',
#    'Van Nest',
#    '2',
#    'Van',
#    'Nest',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-memu.t4ut.ausr',
#    '00000000-0000-0000-C477-8756D9FBF065',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.85040178030428 40.84754906353638)',
#    '34',
#    'Morris Park',
#    '1',
#    'Morris Park',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-ubg6_syjn-vn3z',
#    '00000000-0000-0000-7B7B-74B7D2B546A3',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.88845196134812 40.85727710073898)',
#    '35',
#    'Belmont',
#    '1',
#    'Belmont',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-5rxz.8cu9~2pd3',
#    '00000000-0000-0000-9F55-79092F7C67CB',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.917190482104 40.8813949772709)',
#    '36',
#    'Spuyten Duyvil',
#    '2',
#    'Spuyten',
#    'Duyvil',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-iipb_37pd_56yn',
#    '00000000-0000-0000-A07C-40FDED805BD7',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90453054908934 40.9085428295067)',
#    '37',
#    'North Riverdale',
#    '2',
#    'North',
#    'Riverdale',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-zj3i_agg8.knnb',
#    '00000000-0000-0000-2F81-4F00263536B2',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.83207378240478 40.85064140940339)',
#    '38',
#    'Pelham Bay',
#    '2',
#    'Pelham',
#    'Bay',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-pueg_x9zp_cbe2',
#    '00000000-0000-0000-2C22-9D41AE84DA91',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.82620275994081 40.82657951686926)',
#    '39',
#    'Schuylerville',
#    '1',
#    'Schuylerville',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-umkd-pskf-cry4',
#    '00000000-0000-0000-4C97-1C80E8DF8094',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.81388514428627 40.82198611816354)',
#    '40',
#    'Edgewater Park',
#    '2',
#    'Edgewater',
#    'Park',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-tksz-zim5-gnmc',
#    '00000000-0000-0000-2BBF-01C3C0B9DE86',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.84802729582742 40.81901437698835)',
#    '41',
#    'Castle Hill',
#    '2',
#    'Castle',
#    'Hill',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-ek6r.6gas_znnq',
#    '00000000-0000-0000-8898-4364CF207BA0',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.86332361652784 40.87137078192375)',
#    '42',
#    'Olinville',
#    '1',
#    'Olinville',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-v5ix.t3rx_qiz7',
#    '00000000-0000-0000-5406-42B6E548F35A',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8416119483123 40.862965624780024)',
#    '43',
#    'Pelham Gardens',
#    '2',
#    'Pelham',
#    'Gardens',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-ymm9_j6tg.w3av',
#    '00000000-0000-0000-8790-28C3CA90F765',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91558941773451 40.834283807338544)',
#    '44',
#    'Concourse',
#    '1',
#    'Concourse',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-7ff8_7xu4~nif4',
#    '00000000-0000-0000-ADC1-9315BBCF903C',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.85053524451942 40.82977429787165)',
#    '45',
#    'Unionport',
#    '1',
#    'Unionport',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-t7ms-cpuv-aumq',
#    '00000000-0000-0000-22CD-6FA12FA4D819',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.84808271877175 40.88456130303736)',
#    '46',
#    'Edenwald',
#    '1',
#    'Edenwald',
#    '',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-v2tx_56rz~gkpt',
#    '00000000-0000-0000-73EA-8EE302DE378A',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.03062069353821 40.62580106501069)',
#    '47',
#    'Bay Ridge',
#    '1',
#    'Bay Ridge',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-xycz.y6pp_y9bm',
#    '00000000-0000-0000-3CEE-546D3AF3865D',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.99517998380736 40.61100890202048)',
#    '48',
#    'Bensonhurst',
#    '1',
#    'Bensonhurst',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-v7cj-au6q-3bhq',
#    '00000000-0000-0000-E7A5-BFC77D1CD8C1',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.01031618527792 40.64510294925433)',
#    '49',
#    'Sunset Park',
#    '2',
#    'Sunset',
#    'Park',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-5h6i~g7pk_pm5z',
#    '00000000-0000-0000-E9CE-34FF3E0C15C7',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.954240931274 40.730200984864744)',
#    '50',
#    'Greenpoint',
#    '1',
#    'Greenpoint',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-ygrr-kbyw~sun9',
#    '00000000-0000-0000-A920-46D6EE0A36D3',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.97347087708452 40.59526001306597)',
#    '51',
#    'Gravesend',
#    '1',
#    'Gravesend',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-h3c8.5mmx~6jnu',
#    '00000000-0000-0000-CAE1-76BCF9E7882F',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.96509448785343 40.576825065666085)',
#    '52',
#    'Brighton Beach',
#    '2',
#    'Brighton',
#    'Beach',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-eiq2_2ehe.crwj',
#    '00000000-0000-0000-4B4A-AB8EECE493EC',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.94318640482987 40.58689012678388)',
#    '53',
#    'Sheepshead Bay',
#    '2',
#    'Sheepshead',
#    'Bay',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-d7rj.3gyu-t8ps',
#    '00000000-0000-0000-FA71-5FA7E8A73502',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.95743840559946 40.61443251335102)',
#    '54',
#    'Manhattan Terrace',
#    '2',
#    'Manhattan',
#    'Terrace',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-gyru.fv3f.k35k',
#    '00000000-0000-0000-0498-6AEA889B34AA',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.95840106533912 40.63632589026681)',
#    '55',
#    'Flatbush',
#    '1',
#    'Flatbush',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-fvpt.izhb.euy8',
#    '00000000-0000-0000-C196-AD3B02194E75',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9432911907359 40.67082917695298)',
#    '56',
#    'Crown Heights',
#    '2',
#    'Crown',
#    'Heights',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-rqgh_vu9q~ub3n',
#    '00000000-0000-0000-0E6F-7D55274E3DC0',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.93610256185843 40.64171776668965)',
#    '57',
#    'East Flatbush',
#    '1',
#    'East Flatbush',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-pkb4.44gv_rr82',
#    '00000000-0000-0000-E1DA-650867E3E521',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98042110559481 40.64238195800357)',
#    '58',
#    'Kensington',
#    '1',
#    'Kensington',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-vyqv-cb8v~n92q',
#    '00000000-0000-0000-0F5A-620EC61A20E9',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98007340430179 40.65694583575108)',
#    '59',
#    'Windsor Terrace',
#    '2',
#    'Windsor',
#    'Terrace',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-km4k.qeub~w4sr',
#    '00000000-0000-0000-D187-C10894B8FCC0',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.96485924262697 40.67682226225477)',
#    '60',
#    'Prospect Heights',
#    '2',
#    'Prospect',
#    'Heights',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-xggx-9esc~nucb',
#    '00000000-0000-0000-3B5B-D7E53992A0B5',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91023536176615 40.66394994339758)',
#    '61',
#    'Brownsville',
#    '1',
#    'Brownsville',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-ygrw~hi5z_b9ys',
#    '00000000-0000-0000-6CF4-A7B7890E6325',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.95811529220936 40.70714439344255)',
#    '62',
#    'Williamsburg',
#    '1',
#    'Williamsburg',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-pfvx-q9va_p743',
#    '00000000-0000-0000-4A96-6810EA390AC5',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.92525797487053 40.69811611017905)',
#    '63',
#    'Bushwick',
#    '1',
#    'Bushwick',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-9t2a_bt2y_8r8t',
#    '00000000-0000-0000-1A24-9C9E0AA75EB9',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.94178488690304 40.6872316077205)',
#    '64',
#    'Bedford Stuyvesant',
#    '1',
#    'Bedford Stuyvesant',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-a4jk.ckz8~v2ik',
#    '00000000-0000-0000-CD36-3DDFA19027B8',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.99378225496432 40.69586372272413)',
#    '65',
#    'Brooklyn Heights',
#    '2',
#    'Brooklyn',
#    'Heights',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-qj5x-mnn6_szsz',
#    '00000000-0000-0000-61D1-66B52642DFEB',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9985613921847 40.68791972248561)',
#    '66',
#    'Cobble Hill',
#    '2',
#    'Cobble',
#    'Hill',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-4pnx-a9yb.tnb9',
#    '00000000-0000-0000-B510-EA61547AD576',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.00037274122076 40.68213188564184)',
#    '67',
#    'Carroll Gardens',
#    '2',
#    'Carroll',
#    'Gardens',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-bamm_kqdy_wqt9',
#    '00000000-0000-0000-3921-7F17A13D4486',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.01275897473568 40.67625323025092)',
#    '68',
#    'Red Hook',
#    '2',
#    'Red',
#    'Hook',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-uec4_68t8_6pfi',
#    '00000000-0000-0000-8DE5-9B3F99CFFE9A',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.99444087145346 40.6739311431872)',
#    '69',
#    'Gowanus',
#    '1',
#    'Gowanus',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-5n3p_nqp2_mi2k',
#    '00000000-0000-0000-8043-9F29D7DCDB44',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.97290574369099 40.688527260189815)',
#    '70',
#    'Fort Greene',
#    '2',
#    'Fort',
#    'Greene',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-z3q8~qy34.gqz8',
#    '00000000-0000-0000-72AE-19E6CFAB14E3',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.97705030183931 40.672320522682014)',
#    '71',
#    'Park Slope',
#    '2',
#    'Park',
#    'Slope',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-hwed.a294~jk5e',
#    '00000000-0000-0000-707F-2FDC746EC4F5',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.87583132262635 40.6846357939163)',
#    '72',
#    'Cypress Hills',
#    '2',
#    'Cypress',
#    'Hills',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-n64e~dbjq.qk37',
#    '00000000-0000-0000-192A-76761C3D90DA',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.88069863917373 40.66992570084708)',
#    '73',
#    'East New York',
#    '1',
#    'East New York',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-ipsw~7piy-gbyr',
#    '00000000-0000-0000-D7C2-829A41A4E528',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.87936970045882 40.64758905230878)',
#    '74',
#    'Starrett City',
#    '2',
#    'Starrett',
#    'City',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-dtgu_jqke-amrq',
#    '00000000-0000-0000-FBF5-00CC15CBC1AD',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90209269778973 40.63556432797432)',
#    '75',
#    'Canarsie',
#    '1',
#    'Canarsie',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-edpk_49fn_fqzf',
#    '00000000-0000-0000-B3BD-D30CD6E79B1C',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.92911302644681 40.6304460437575)',
#    '76',
#    'Flatlands',
#    '1',
#    'Flatlands',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-dz9j.wtjp-yqcz',
#    '00000000-0000-0000-5087-CA359DAF2941',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90818571777432 40.60633642168567)',
#    '77',
#    'Mill Island',
#    '2',
#    'Mill',
#    'Island',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-bdf7-r66f.c9iz',
#    '00000000-0000-0000-A646-54A21229445D',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.94353722891894 40.57791350308661)',
#    '78',
#    'Manhattan Beach',
#    '2',
#    'Manhattan',
#    'Beach',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-qznu_f5bc.n757',
#    '00000000-0000-0000-2D09-5EA30B85D566',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98868295821644 40.57429256471605)',
#    '79',
#    'Coney Island',
#    '1',
#    'Coney Island',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-vntw_tfi9.d6c2',
#    '00000000-0000-0000-2AF3-BF1D1CBBD8DD',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.99875221443526 40.599518702822415)',
#    '80',
#    'Bath Beach',
#    '2',
#    'Bath',
#    'Beach',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-7ea4_53p4~4q2m',
#    '00000000-0000-0000-C856-8193A63DEE13',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.99049823044818 40.63313051275805)',
#    '81',
#    'Borough Park',
#    '2',
#    'Borough',
#    'Park',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-mxsm-nybk_42qt',
#    '00000000-0000-0000-668D-67CEB49F79D0',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.01931375636029 40.61921945772268)',
#    '82',
#    'Dyker Heights',
#    '2',
#    'Dyker',
#    'Heights',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-894q~xgrk.ctit',
#    '00000000-0000-0000-F8A4-1182CF7308B6',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.93010170691203 40.59084843390208)',
#    '83',
#    'Gerritsen Beach',
#    '2',
#    'Gerritsen',
#    'Beach',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-gkew_t2qy-tv5e',
#    '00000000-0000-0000-72C7-95F652C4E142',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.93134404108504 40.60974777989464)',
#    '84',
#    'Marine Park',
#    '1',
#    'Marine Park',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-deu7.5iby_mphh',
#    '00000000-0000-0000-DF7C-FFF0251E05E6',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.96784306216374 40.69322942188155)',
#    '85',
#    'Clinton Hill',
#    '2',
#    'Clinton',
#    'Hill',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-tsk3_v57b~agcs',
#    '00000000-0000-0000-52D4-7B1BB58C0C4B',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.00787311200247 40.576375378902284)',
#    '86',
#    'Sea Gate',
#    '2',
#    'Sea',
#    'Gate',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-4zms.bnc6~g8bw',
#    '00000000-0000-0000-4A1D-86DAA22F1240',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98346337431106 40.69084402109806)',
#    '87',
#    'Downtown',
#    '2',
#    'Down-',
#    'town',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-9z69~rpu5.nb5c',
#    '00000000-0000-0000-CA1A-F5FF386D8578',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98357724689187 40.687241380657376)',
#    '88',
#    'Boerum Hill',
#    '2',
#    'Boerum',
#    'Hill',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-q44m~trrh_ii4p',
#    '00000000-0000-0000-DAD2-7DF64C1C35D9',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9548986707772 40.65842001746986)',
#    '89',
#    'Prospect Lefferts Gardens',
#    '3',
#    'Prospect',
#    'Lefferts',
#    'Gardens',
#    '0.0',
#    'Brooklyn'],
#   ['row-d6hb~yyxj.va5t',
#    '00000000-0000-0000-7722-9F2D892FEBF6',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91306831787404 40.6784025547954)',
#    '90',
#    'Ocean Hill',
#    '2',
#    'Ocean',
#    'Hill',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-sdkp_cz9v.chzg',
#    '00000000-0000-0000-BB38-48262E84B120',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.86797598081343 40.678569957274824)',
#    '91',
#    'City Line',
#    '2',
#    'City',
#    'Line',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-e9zd_tn8y.ahaz',
#    '00000000-0000-0000-DE51-736B69516A18',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.89855633630324 40.615149550453125)',
#    '92',
#    'Bergen Beach',
#    '2',
#    'Bergen',
#    'Beach',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-arxt.5ir9-egpf',
#    '00000000-0000-0000-F654-65CAC066F843',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.95759523489846 40.62559589869847)',
#    '93',
#    'Midwood',
#    '1',
#    'Midwood',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-6mwk.mw2s_r58x',
#    '00000000-0000-0000-D09B-E3B8C738DADE',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.96261316716055 40.64700860318523)',
#    '94',
#    'Prospect Park South',
#    '2',
#    'Prospect',
#    'Park South',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-q2kw.i54z.7pyi',
#    '00000000-0000-0000-614C-5BD13966AE48',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91607483951331 40.623845244784235)',
#    '95',
#    'Georgetown',
#    '1',
#    'Georgetown',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-dpny-mxvb~nzbq',
#    '00000000-0000-0000-553F-53848B9123F6',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.86998779106547 40.65713927658277)',
#    '96',
#    'Spring Creek',
#    '2',
#    'Spring',
#    'Creek',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-uc97_k3uc-xbxg',
#    '00000000-0000-0000-EB7A-A3CD759FC13B',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.93885815269203 40.70849241041552)',
#    '97',
#    'East Williamsburg',
#    '2',
#    'East',
#    'Williamsburg',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-7zqr.biz7_vzbs',
#    '00000000-0000-0000-5AB6-84D3EF6C2EFF',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.95880857587589 40.714822906532056)',
#    '98',
#    'North Side',
#    '1',
#    'North Side',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-7uhf~uhax.apjx',
#    '00000000-0000-0000-C5BC-8C4F77D303CC',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.95800095153338 40.710861472650684)',
#    '99',
#    'South Side',
#    '1',
#    'South Side',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-8xd9~azay-ukyi',
#    '00000000-0000-0000-E0ED-989B374FBFDC',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.97164435527614 40.698790872180545)',
#    '100',
#    'Navy Yard',
#    '2',
#    'Navy',
#    'Yard',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-tuy2_kx39_gmpd',
#    '00000000-0000-0000-32BD-BD73530D588D',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.96836678035548 40.61305976667946)',
#    '101',
#    'Ocean Parkway',
#    '2',
#    'Ocean',
#    'Parkway',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-s2jm_bkcx_6hya',
#    '00000000-0000-0000-62F2-8888C45FF8AD',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.0319791453799 40.6147681269423)',
#    '102',
#    'Fort Hamilton',
#    '2',
#    'Fort',
#    'Hamilton',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-7f7f.gn66_53cc',
#    '00000000-0000-0000-9662-346E67BA0C47',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.99427936255985 40.715618422314364)',
#    '103',
#    'Chinatown',
#    '1',
#    'Chinatown',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-fann~xnhm-yr7a',
#    '00000000-0000-0000-238D-6DB3673AA9EB',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.93690027985242 40.85190252555309)',
#    '104',
#    'Washington Heights',
#    '2',
#    'Washington',
#    'Heights',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-qjtv~yjds~nmac',
#    '00000000-0000-0000-E84F-0C79D30D9412',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.92121042203905 40.86768396449919)',
#    '105',
#    'Inwood',
#    '1',
#    'Inwood',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-37av~wzzb_zg2z',
#    '00000000-0000-0000-AF86-5AD2B323DA8D',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.94968791883373 40.82360428481197)',
#    '106',
#    'Hamilton Heights',
#    '2',
#    'Hamilton',
#    'Heights',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-xqy3.vsyc~iuub',
#    '00000000-0000-0000-5430-3A9E397960B7',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.95738539351888 40.81693442949784)',
#    '107',
#    'Manhattanville',
#    '2',
#    'Manhattanville',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-qh99_v6wi_73z3',
#    '00000000-0000-0000-520B-589B1C554A7C',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.94321112603912 40.81597606742418)',
#    '108',
#    'Central Harlem',
#    '2',
#    'Central',
#    'Harlem',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-cnad-gnc6.ru9v',
#    '00000000-0000-0000-B70F-DF67A15B4F97',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.94418223148531 40.79224946663037)',
#    '109',
#    'East Harlem',
#    '2',
#    'East',
#    'Harlem',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-eaw5_z5za-ifx2',
#    '00000000-0000-0000-EC75-7B9C155C6FCC',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.96050763135007 40.77563857330185)',
#    '110',
#    'Upper East Side',
#    '3',
#    'Upper',
#    'East',
#    'Side',
#    '0.0',
#    'Manhattan'],
#   ['row-tj66-d2tq_asb2',
#    '00000000-0000-0000-A73C-B70FF68E6441',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.94711784471833 40.77592984988492)',
#    '111',
#    'Yorkville',
#    '2',
#    'York-',
#    'ville',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-p8wa.7tve.eym9',
#    '00000000-0000-0000-CD54-72D3633ED57F',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.95885968813766 40.76811265828737)',
#    '112',
#    'Lenox Hill',
#    '2',
#    'Lenox',
#    'Hill',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-ebyi~pg9s-dska',
#    '00000000-0000-0000-97FA-0ADC14D93FD3',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9494705736962 40.762403730702246)',
#    '113',
#    'Roosevelt Island',
#    '1',
#    'Roosevelt Island',
#    '',
#    '',
#    '56.0',
#    'Manhattan'],
#   ['row-u8fa_wiw3-rvq7',
#    '00000000-0000-0000-DFB8-FD8245C048CE',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9770592363061 40.7876579985349)',
#    '114',
#    'Upper West Side',
#    '3',
#    'Upper',
#    'West',
#    'Side',
#    '0.0',
#    'Manhattan'],
#   ['row-akcm-bfcu.i3h5',
#    '00000000-0000-0000-7343-217C892891AF',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9853377700127 40.773528889421705)',
#    '115',
#    'Lincoln Square',
#    '2',
#    'Lincoln',
#    'Square',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-9e42_4c8g_93ee',
#    '00000000-0000-0000-CB1E-FCD562000B5C',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.99640768221386 40.758333686906404)',
#    '116',
#    'Clinton',
#    '1',
#    'Clinton',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-bgvm.arkx_zyw5',
#    '00000000-0000-0000-1E51-D41852948069',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98166882730311 40.75469110270627)',
#    '117',
#    'Midtown',
#    '1',
#    'Midtown',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-hkbw~2r2d-2biv',
#    '00000000-0000-0000-7007-F1E281254099',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.97833207924134 40.74830307725222)',
#    '118',
#    'Murray Hill',
#    '2',
#    'Murray',
#    'Hill',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-dbus_iubn.6szi',
#    '00000000-0000-0000-0EB8-7AF1679EB786',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.0031163347282 40.74403470674802)',
#    '119',
#    'Chelsea',
#    '1',
#    'Chelsea',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-s2jz~vibg_6fsj',
#    '00000000-0000-0000-1D7B-9CFBA7BD4DD7',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.99991402945909 40.72693288536132)',
#    '120',
#    'Greenwich Village',
#    '2',
#    'Greenwich',
#    'Village',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-4xcs.23xf-j6zu',
#    '00000000-0000-0000-2277-96156C08CD9B',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98222616506425 40.72784677727029)',
#    '121',
#    'East Village',
#    '2',
#    'East',
#    'Village',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-bcq4.5jqv_htdu',
#    '00000000-0000-0000-4ACC-142DB4D86F64',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98089031999298 40.71780674892769)',
#    '122',
#    'Lower East Side',
#    '3',
#    'Lower',
#    'East',
#    'Side',
#    '0.0',
#    'Manhattan'],
#   ['row-t73b.z2rh.6inf',
#    '00000000-0000-0000-4C58-F4E2CA987A35',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.01068328559094 40.72152196744325)',
#    '123',
#    'Tribeca',
#    '1',
#    'Tribeca',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-tjjb~fpqz-qe7a',
#    '00000000-0000-0000-E2F2-13748ED71E31',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9973046720808 40.71932379395911)',
#    '124',
#    'Little Italy',
#    '2',
#    'Little',
#    'Italy',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-ie39_fuy5-c99n',
#    '00000000-0000-0000-0CD8-30B327955ACD',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.00065666959766 40.72218384131798)',
#    '125',
#    'Soho',
#    '1',
#    'Soho',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-fw94-ghb4_2svq',
#    '00000000-0000-0000-5EB6-2A8801153236',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.00617998126819 40.734433935724375)',
#    '126',
#    'West Village',
#    '2',
#    'West',
#    'Village',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-eyrp~f864~28ct',
#    '00000000-0000-0000-EEF5-6CB120090B23',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.96428617740662 40.7973070417029)',
#    '127',
#    'Manhattan Valley',
#    '2',
#    'Manhattan',
#    'Valley',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-7iwh.94s5-5kzg',
#    '00000000-0000-0000-4A2E-F7110800D967',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.96389627905339 40.80799973816586)',
#    '128',
#    'Morningside Heights',
#    '2',
#    'Morningside',
#    'Heights',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-3jrv_vhid_p7d4',
#    '00000000-0000-0000-331D-FFC7E710D25E',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98137594833548 40.737209832715045)',
#    '129',
#    'Gramercy',
#    '1',
#    'Gramercy',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-2np8.i8ki~pqnn',
#    '00000000-0000-0000-7A56-16459A77BF37',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.01686930508625 40.71193198394569)',
#    '130',
#    'Battery Park City',
#    '3',
#    'Battery',
#    'Park',
#    'City',
#    '0.0',
#    'Manhattan'],
#   ['row-w6zy.3ac4-9cjf',
#    '00000000-0000-0000-8E72-92C11FA53558',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.01066544521277 40.70710710727052)',
#    '131',
#    'Financial District',
#    '2',
#    'Financial',
#    'District',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-xnq7~fpib-ad3k',
#    '00000000-0000-0000-0170-37210B190566',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91565374304241 40.768508593354966)',
#    '132',
#    'Astoria',
#    '1',
#    'Astoria',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-uq9c~c3rk_bdsb',
#    '00000000-0000-0000-F875-219662C6CB53',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90184166838291 40.746349088602265)',
#    '133',
#    'Woodside',
#    '1',
#    'Woodside',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-nf4m_8c68.ruyi',
#    '00000000-0000-0000-B5AF-34304CFD1691',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.88282109164372 40.751981380073715)',
#    '134',
#    'Jackson Heights',
#    '2',
#    'Jackson',
#    'Heights',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-xqjq~pu5j-e2nx',
#    '00000000-0000-0000-D10D-1FC42CA1AE27',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.88165622288396 40.744048505122066)',
#    '135',
#    'Elmhurst',
#    '1',
#    'Elmhurst',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-z5xw.k99m~vham',
#    '00000000-0000-0000-9895-C5C673AD0056',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.83813764600289 40.6542252773849)',
#    '136',
#    'Howard Beach',
#    '2',
#    'Howard',
#    'Beach',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-zf6u_ihsm_3ynh',
#    '00000000-0000-0000-8749-066B93A1D8BB',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.85682497345266 40.7423817501567)',
#    '137',
#    'South Corona',
#    '2',
#    'South',
#    'Corona',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-e272-3wpa_rhcp',
#    '00000000-0000-0000-75A8-A5B925734D3B',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8444750078899 40.725263782165065)',
#    '138',
#    'Forest Hills',
#    '2',
#    'Forest',
#    'Hills',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-zfdt.w6iy.c6ze',
#    '00000000-0000-0000-2FA7-54854F983F39',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8298190582571 40.705179035414844)',
#    '139',
#    'Kew Gardens',
#    '2',
#    'Kew',
#    'Gardens',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-a78q.vsn7_fiiq',
#    '00000000-0000-0000-BCF7-BCDFE0D0DEA3',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.83183321446894 40.69794731471767)',
#    '140',
#    'Richmond Hill',
#    '2',
#    'Richmond',
#    'Hill',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-n3xq-8ax4~m4iv',
#    '00000000-0000-0000-5206-C5C476E6E20C',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.82936758711861 40.76116362081876)',
#    '141',
#    'Downtown Flushing',
#    '2',
#    'Downtown',
#    'Flushing',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-4n9g.nrec-jsc8',
#    '00000000-0000-0000-95EE-A8A761B6910A',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.93920223915512 40.75021734610532)',
#    '142',
#    'Long Island City',
#    '3',
#    'Long',
#    'Island',
#    'City',
#    '0.0',
#    'Queens'],
#   ['row-36rf~zwn6-kem4',
#    '00000000-0000-0000-A5BF-B4A842A78A4A',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.92691617561584 40.74017628351928)',
#    '143',
#    'Sunnyside',
#    '1',
#    'Sunnyside',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-7e9x_dzbr_d29h',
#    '00000000-0000-0000-E1AB-3AD4CA7A6792',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.86704147658779 40.764073238830946)',
#    '144',
#    'East Elmhurst',
#    '2',
#    'East',
#    'Elmhurst',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-ibfs.9qh5_izse',
#    '00000000-0000-0000-8D31-A51FC2F9B479',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.89621713626867 40.72542737409365)',
#    '145',
#    'Maspeth',
#    '1',
#    'Maspeth',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-paji-49xr_a8na',
#    '00000000-0000-0000-8690-C85FCB8E895A',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90143517559596 40.70832315613862)',
#    '146',
#    'Ridgewood',
#    '1',
#    'Ridgewood',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-v7wk-s8ye.rn9d',
#    '00000000-0000-0000-EDB7-887D1C53DAD9',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.87074167435614 40.702762429678415)',
#    '147',
#    'Glendale',
#    '1',
#    'Glendale',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-cgip.hxtb_akvu',
#    '00000000-0000-0000-6820-ED6EE5B95C61',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.85782686905377 40.72897409480739)',
#    '148',
#    'Rego Park',
#    '1',
#    'Rego Park',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-6ge4~v6kd.frzg',
#    '00000000-0000-0000-4265-A6D8D2EA1959',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.85811046554328 40.689886879157925)',
#    '149',
#    'Woodhaven',
#    '1',
#    'Woodhaven',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-4nn7_y83a-uf2b',
#    '00000000-0000-0000-0374-77FF52D084F2',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.84320266173454 40.68070846826546)',
#    '150',
#    'Ozone Park',
#    '1',
#    'Ozone Park',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-78uq~rjfq~a5fb',
#    '00000000-0000-0000-76A8-83606E8DA480',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.80986478649048 40.66854957767199)',
#    '151',
#    'South Ozone Park',
#    '2',
#    'South',
#    'Ozone Park',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-rgqk_fkgt_xans',
#    '00000000-0000-0000-1B1E-0D8AEEFCC4E9',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.84304528896132 40.78490274926025)',
#    '152',
#    'College Point',
#    '2',
#    'College',
#    'Point',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-m5aq~ukyf.8i8x',
#    '00000000-0000-0000-1DEF-73B6E601C90D',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8142021661087 40.781290766026984)',
#    '153',
#    'Whitestone',
#    '1',
#    'Whitestone',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-wgat-iwdq_a4x3',
# ...
#    '242',
#    'Charleston',
#    '1',
#    'Charleston',
#    '',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-g9uq-2zdt.9jsy',
#    '00000000-0000-0000-6326-7EE38CDC4F1B',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.21572851113959 40.549404006500765)',
#    '243',
#    'Rossville',
#    '1',
#    'Rossville',
#    '',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-jrde_g538.6mdm',
#    '00000000-0000-0000-52D1-F7CE7213CD02',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.185886745839 40.549285822783254)',
#    '244',
#    'Arden Heights',
#    '2',
#    'Arden',
#    'Heights',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-gpgi.mbkw~jkvf',
#    '00000000-0000-0000-2D87-3D63629FD702',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.19150620964295 40.559712496342954)',
#    '245',
#    'Greenridge',
#    '1',
#    'Greenridge',
#    '',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-jueh-qh36~diyr',
#    '00000000-0000-0000-B544-114FDBBBE67B',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.15902208156608 40.589138948752854)',
#    '246',
#    'Heartland Village',
#    '2',
#    'Heartland',
#    'Village',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-c3tw.bzxk~nv4a',
#    '00000000-0000-0000-BA0A-F5364F2BBE87',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.18956045519697 40.59472602746298)',
#    '247',
#    'Chelsea',
#    '1',
#    'Chelsea',
#    '',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-8tph.hfkj~idvw',
#    '00000000-0000-0000-F27F-ACFFEC6D2758',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.18725638381574 40.60577868452362)',
#    '248',
#    'Bloomfield',
#    '1',
#    'Bloomfield',
#    '',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-ruvn_668i-9jd9',
#    '00000000-0000-0000-5D72-BC82492FFC07',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.15940948657129 40.60959180042034)',
#    '249',
#    'Bulls Head',
#    '2',
#    'Bulls',
#    'Head',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-7sqs~tveq-f6r4',
#    '00000000-0000-0000-93A0-9133D8A0BF5F',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.95325646837121 40.78268256712574)',
#    '250',
#    'Carnegie Hill',
#    '2',
#    'Carnegie',
#    'Hill',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-v37f_fjfs.hqyk',
#    '00000000-0000-0000-4031-0B03D33E5177',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98843368023604 40.72325901885772)',
#    '251',
#    'Noho',
#    '1',
#    'Noho',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-z748-a2wt.drsi',
#    '00000000-0000-0000-50C1-8E8D3D57C214',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.00541529873362 40.715228920462856)',
#    '252',
#    'Civic Center',
#    '2',
#    'Civic',
#    'Center',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-my5a~wu4h.pa6a',
#    '00000000-0000-0000-1A79-252E586FC188',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98871313285254 40.748509664312245)',
#    '253',
#    'Midtown South',
#    '2',
#    'Midtown',
#    'South',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-3s7b_usyc_3fwx',
#    '00000000-0000-0000-FB2A-590363EBDB11',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.13405729862578 40.56960594275509)',
#    '254',
#    'Richmond Town',
#    '2',
#    'Richmond',
#    'Town',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-g5ph~nrwp-w4st',
#    '00000000-0000-0000-D5CE-F2C42BCA2AA8',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.06667766061778 40.609719340792886)',
#    '255',
#    'Shore Acres',
#    '2',
#    'Shore',
#    'Acres',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-kjw3_45aq-tn6p',
#    '00000000-0000-0000-D66E-EE80D94B8E03',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.07264244548406 40.61917845202847)',
#    '256',
#    'Clifton',
#    '1',
#    'Clifton',
#    '',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-p3p3.674t.75n4',
#    '00000000-0000-0000-F05B-F3F82A1CB23E',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.08402364740365 40.604473189687944)',
#    '257',
#    'Concord',
#    '1',
#    'Concord',
#    '',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-ujma~dh3q.fj74',
#    '00000000-0000-0000-1959-75D5B797C4CA',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.09776206972529 40.606794394801035)',
#    '258',
#    'Emerson Hill',
#    '2',
#    'Emerson',
#    'Hill',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-qz5i-qhet-cjm4',
#    '00000000-0000-0000-98DF-D3D336E87B50',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.09805062373894 40.63563000681155)',
#    '259',
#    'Randall Manor',
#    '2',
#    'Randall',
#    'Manor',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-3v8f_6i9i~688d',
#    '00000000-0000-0000-282C-4FB91D716362',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.1862233174983 40.638432837947995)',
#    '260',
#    'Howland Hook',
#    '2',
#    'Howland',
#    'Hook',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-c7pf.xea4-8fbz',
#    '00000000-0000-0000-5C00-C386793CABC9',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.14181678968897 40.63014674119387)',
#    '261',
#    'Elm Park',
#    '2',
#    'Elm',
#    'Park',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-9zpx.m4pm~chhd',
#    '00000000-0000-0000-8219-31D6F1515DE3',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91665331978055 40.65211745179353)',
#    '262',
#    'Remsen Village',
#    '2',
#    'Remsen',
#    'Village',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-tr53-jgxg_6xm8',
#    '00000000-0000-0000-6AEF-2F08B0AF7347',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.885117763793 40.66274427969663)',
#    '263',
#    'New Lots',
#    '2',
#    'New',
#    'Lots',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-vpik.s7hx-www3',
#    '00000000-0000-0000-C9F5-ADB95443010B',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90233474295843 40.63131755039671)',
#    '264',
#    'Paerdegat Basin',
#    '2',
#    'Paerdegat',
#    'Basin',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-urrm.ddqj_e79y',
#    '00000000-0000-0000-B4CB-49FD1175507C',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9151539155041 40.615974239623405)',
#    '265',
#    'Mill Basin',
#    '2',
#    'Mill',
#    'Basin',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-yxgw~25rv_8bab',
#    '00000000-0000-0000-50A7-9836143301E8',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.796464620816 40.71145964370486)',
#    '266',
#    'Jamaica Hills',
#    '2',
#    'Jamaica',
#    'Hills',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-zi2t~f6qx_ni6m',
#    '00000000-0000-0000-BB7C-A89BF62810C6',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.79671678028357 40.7335002542976)',
#    '267',
#    'Utopia',
#    '1',
#    'Utopia',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-fev6.z4up.m96a',
#    '00000000-0000-0000-5D33-EF344201971B',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.80486120040544 40.73493618075482)',
#    '268',
#    'Pomonok',
#    '1',
#    'Pomonok',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-6nup_6rf9.uuk6',
#    '00000000-0000-0000-35E3-263067863C14',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.89467996270581 40.770317392998244)',
#    '269',
#    'Astoria Heights',
#    '2',
#    'Astoria',
#    'Heights',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-u76d-if3b-aqii',
#    '00000000-0000-0000-F0D7-466212A7E042',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90119903387674 40.83142834161551)',
#    '270',
#    'Claremont Village',
#    '2',
#    'Claremont',
#    'Village',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-zj93~tddi.rhrf',
#    '00000000-0000-0000-B985-62639F596B44',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91584652759016 40.82478049084294)',
#    '271',
#    'Concourse Village',
#    '2',
#    'Concourse',
#    'Village',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-bu7d_r4mv-67z9',
#    '00000000-0000-0000-EAA2-962FB8D9C19C',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.91655551964426 40.843826176716576)',
#    '272',
#    'Mount Eden',
#    '2',
#    'Mount',
#    'Eden',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-zimx~ur9r-r5w4',
#    '00000000-0000-0000-CAC4-4F11EC22817A',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90829930881995 40.84884160724669)',
#    '273',
#    'Mount Hope',
#    '2',
#    'Mount',
#    'Hope',
#    '',
#    '0.0',
#    'Bronx'],
#   ['row-cq99-c3az~zgiw',
#    '00000000-0000-0000-83BB-7DD75D9B5BF7',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9635561409431 40.76028033131378)',
#    '274',
#    'Sutton Place',
#    '2',
#    'Sutton',
#    'Place',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-deyn.xh8q_2yqa',
#    '00000000-0000-0000-AFDF-08CC54F32F05',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.95386782130753 40.74341409007358)',
#    '275',
#    'Hunters Point',
#    '2',
#    'Hunters',
#    'Point',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-6jq2-ju76-drui',
#    '00000000-0000-0000-1E3F-A773B8F019A9',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.96770824581843 40.75204236950726)',
#    '276',
#    'Turtle Bay',
#    '2',
#    'Turtle',
#    'Bay',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-494s_bi5b_rb69',
#    '00000000-0000-0000-1436-2C5DE1365841',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.97121928722272 40.74691741074023)',
#    '277',
#    'Tudor City',
#    '2',
#    'Tudor',
#    'City',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-qam6_hps6_iq2n',
#    '00000000-0000-0000-3107-2B2628EA63F1',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9740517046921 40.73099955477065)',
#    '278',
#    'Stuyvesant Town',
#    '2',
#    'Stuyvesant',
#    'Town',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-3b7c-z238.knhi',
#    '00000000-0000-0000-02A0-2ABFFB5799ED',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.99094710528267 40.73967304763847)',
#    '279',
#    'Flatiron',
#    '1',
#    'Flatiron',
#    '',
#    '',
#    '0.0',
#    'Manhattan'],
#   ['row-4fkr_73dg.rua7',
#    '00000000-0000-0000-3541-BB44B2CD1CEE',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9181928643169 40.745651806080794)',
#    '280',
#    'Sunnyside Gardens',
#    '2',
#    'Sunnyside',
#    'Gardens',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-92se~jt3c.uxsm',
#    '00000000-0000-0000-F780-1A044F80570E',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.93244235260185 40.73725071694501)',
#    '281',
#    'Blissville',
#    '1',
#    'Blissville',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-ifrc~ccgz-5bxy',
#    '00000000-0000-0000-A8E7-5AD63A0EA264',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.99550751888422 40.70328109093018)',
#    '282',
#    'Fulton Ferry',
#    '2',
#    'Fulton',
#    'Ferry',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-stje~7m4s_znrf',
#    '00000000-0000-0000-26BC-CBF17D70ED7A',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.981116035924 40.703321498828785)',
#    '283',
#    'Vinegar Hill',
#    '2',
#    'Vinegar',
#    'Hill',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-ks28_xjpe_7y7f',
#    '00000000-0000-0000-60A1-7A3C8AA1948E',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.93053108817347 40.67503986503241)',
#    '284',
#    'Weeksville',
#    '1',
#    'Weeksville',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-xbrj_wkxx_5kgc',
#    '00000000-0000-0000-60E5-558F5F47C0F1',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.90331684852606 40.67786104769535)',
#    '285',
#    'Broadway Junction',
#    '2',
#    'Broadway',
#    'Junction',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-9p3m~3stb-nhmx',
#    '00000000-0000-0000-91DA-B01DC455A363',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.98875280745047 40.70317632822696)',
#    '286',
#    'Dumbo',
#    '1',
#    'Dumbo',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-vvne.jve2~zcbh',
#    '00000000-0000-0000-1CFA-7AF0FA0C9CF9',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.12059399718008 40.60180957631448)',
#    '287',
#    'Manor Heights',
#    '2',
#    'Manor',
#    'Heights',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-967h_gm22-msvf',
#    '00000000-0000-0000-A496-D5009017A412',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.13208447484305 40.60370692627375)',
#    '288',
#    'Willowbrook',
#    '1',
#    'Willowbrook',
#    '',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-t67i.md8x.x7j9',
#    '00000000-0000-0000-693A-2E0A63768FB5',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.21776636068574 40.5411399220918)',
#    '289',
#    'Sandy Ground',
#    '2',
#    'Sandy',
#    'Ground',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-ii3x-xcng_fwpr',
#    '00000000-0000-0000-822F-1A105D2A30E8',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.12727240604953 40.579118742961256)',
#    '290',
#    'Egbertville',
#    '1',
#    'Egbertville',
#    '',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-7wp3.j3gk.5t32',
#    '00000000-0000-0000-EDA1-09DF9B1DB068',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.89213760232829 40.567375889570364)',
#    '291',
#    'Roxbury',
#    '1',
#    'Roxbury',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-8gua.4hed.nq2p',
#    '00000000-0000-0000-2BFD-2BA3F6555DA2',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.9591845942871 40.59852509513729)',
#    '292',
#    'Homecrest',
#    '1',
#    'Homecrest',
#    '',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-xn4m-byqq.5k98',
#    '00000000-0000-0000-85C8-90E8B2588807',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8811431920061 40.71641451115823)',
#    '293',
#    'Middle Village',
#    '2',
#    'Middle',
#    'Village',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-v8v2_fp8c_37r6',
#    '00000000-0000-0000-9977-ADFFA5D465BA',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.20152556457666 40.526264067348166)',
#    '294',
#    "Prince's Bay",
#    '2',
#    "Prince's",
#    'Bay',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-8sei-j7c4_k8fd',
#    '00000000-0000-0000-8555-3EAB5F2CBDF3',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.13792663771576 40.576506293794935)',
#    '295',
#    'Lighthouse Hill',
#    '2',
#    'Lighthouse',
#    'Hill',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-c7hs.bcnk.grxp',
#    '00000000-0000-0000-F9F9-F62F8239408D',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-74.22957080626948 40.519541457489126)',
#    '296',
#    'Richmond Valley',
#    '2',
#    'Richmond',
#    'Valley',
#    '',
#    '0.0',
#    'Staten Island'],
#   ['row-c6kz-7avp~z7tf',
#    '00000000-0000-0000-B61E-D4974D7DC062',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8266775713865 40.790601556701525)',
#    '297',
#    'Malba',
#    '1',
#    'Malba',
#    '',
#    '',
#    '0.0',
#    'Queens'],
#   ['row-axq5-ce4k-3hm8',
#    '00000000-0000-0000-D134-71887F079A30',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.8902809854761 40.68248551101694)',
#    '298',
#    'Highland Park',
#    '2',
#    'Highland',
#    'Park',
#    '',
#    '0.0',
#    'Brooklyn'],
#   ['row-9hbu-jduc_7cjj',
#    '00000000-0000-0000-4A3F-10891D0BB287',
#    0,
#    1450726363,
#    None,
#    1450726363,
#    None,
#    '{ }',
#    'POINT (-73.948415153289 40.609377701137696)',
#    '299',
#    'Madison',
#    '1',
#    'Madison',
#    '',
#    '',
#    '0.0',
#    'Brooklyn']]}

# %%
neighborhoods_data = newyork_data['data']

# %%
neighborhoods_data[1]
# Out:
# ['row-s456-uyfi_n9s7',
#  '00000000-0000-0000-20BE-C45ADF984BA3',
#  0,
#  1450726363,
#  None,
#  1450726363,
#  None,
#  '{ }',
#  'POINT (-73.82993910812405 40.87429419303015)',
#  '2',
#  'Co-op City',
#  '2',
#  'Co-op',
#  'City',
#  '',
#  '0.0',
#  'Bronx']

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
neighborhoods
# Out:
# Empty DataFrame
# Columns: [Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data[16] 
    neighborhood_name = data[10]
        
    val = data[8].split('(', 1)[1].split(')')[0]
    neighborhood_latlon = val.split()
    neighborhood_lat = neighborhood_latlon[0]
    neighborhood_lon = neighborhood_latlon[1]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
neighborhoods.head()
# Out:
#   Borough Neighborhood            Latitude           Longitude
# 0   Bronx    Wakefield   -73.8472005205491   40.89470517661004
# 1   Bronx   Co-op City  -73.82993910812405   40.87429419303015
# 2   Bronx  Eastchester  -73.82780644716419   40.88755567735082
# 3   Bronx    Fieldston  -73.90564259591689  40.895437426903875
# 4   Bronx    Riverdale  -73.91258546108577   40.89083449389134

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 299 neighborhoods.

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
queens_data = neighborhoods[neighborhoods['Borough'] == 'Queens'].reset_index(drop=True)
queens_data.head()
# Out:
#   Borough     Neighborhood            Latitude           Longitude
# 0  Queens          Astoria  -73.91565374304241  40.768508593354966
# 1  Queens         Woodside  -73.90184166838291  40.746349088602265
# 2  Queens  Jackson Heights  -73.88282109164372  40.751981380073715
# 3  Queens         Elmhurst  -73.88165622288396  40.744048505122066
# 4  Queens     Howard Beach  -73.83813764600289    40.6542252773849

# %%
address = 'Queens, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Queens are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Queens are 40.7498243, -73.7976337.

# %%
# create map of Manhattan using latitude and longitude values
map_queens = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(queens_data['Latitude'], queens_data['Longitude'], queens_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_queens)  
    
map_queens
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Using Foursquare API

# %%
CLIENT_ID = 'QE4UWQWDE1HS4Z15MUCAG3V2NW4BMV3KXNMJK5AQVY0CIBIL' # your Foursquare ID
CLIENT_SECRET = 'K5GA3VT1GJVEP3HPKMARARBYQGDZFYLMFADVX2NBLRZQ1SU3' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QE4UWQWDE1HS4Z15MUCAG3V2NW4BMV3KXNMJK5AQVY0CIBIL
# CLIENT_SECRET:K5GA3VT1GJVEP3HPKMARARBYQGDZFYLMFADVX2NBLRZQ1SU3

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=QE4UWQWDE1HS4Z15MUCAG3V2NW4BMV3KXNMJK5AQVY0CIBIL&client_secret=K5GA3VT1GJVEP3HPKMARARBYQGDZFYLMFADVX2NBLRZQ1SU3&v=20180605&ll=40.7498243,-73.7976337&radius=500&limit=100'

# %%
results = requests.get(url).json()
#results

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                        name         categories        lat        lng
# 0     Pado Sushi Restaurant  Korean Restaurant  40.753599 -73.794425
# 1       Western Riding Club        Sports Club  40.749359 -73.797699
# 2  Underhill Ave Bike Trail         Bike Trail  40.747286 -73.799391
# 3        MTA - Q65 Bus Stop        Bus Station  40.748537 -73.801613

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
queens_data.shape
# Out:
# (78, 4)

# %%
queens_venues = getNearbyVenues(names= queens_data['Neighborhood'],
                                   latitudes= queens_data['Latitude'],
                                   longitudes= queens_data['Longitude'],
                                  )
# Out:
# Astoria
# Woodside
# Jackson Heights
# Elmhurst
# Howard Beach
# South Corona
# Forest Hills
# Kew Gardens
# Richmond Hill
# Downtown Flushing
# Long Island City
# Sunnyside
# East Elmhurst
# Maspeth
# Ridgewood
# Glendale
# Rego Park
# Woodhaven
# Ozone Park
# South Ozone Park
# College Point
# Whitestone
# Bayside
# Auburndale
# Little Neck
# Douglaston
# Glen Oaks
# Bellerose
# Kew Gardens Hills
# Fresh Meadows
# Briarwood
# Jamaica Center
# Oakland Gardens
# Queens Village
# Hollis
# South Jamaica
# St. Albans
# Rochdale
# Springfield Gardens
# Cambria Heights
# Rosedale
# Far Rockaway
# Broad Channel
# Breezy Point
# Steinway
# Beechhurst
# Bay Terrace
# Edgemere
# Arverne
# Seaside
# Neponsit
# Murray Hill
# Floral Park
# Holliswood
# Jamaica Estates
# Queensboro Hill
# Hillcrest
# Ravenswood
# Lindenwood
# Laurelton
# Lefrak City
# Belle Harbor
# Rockaway Park
# Somerville
# Brookville
# Bellaire
# North Corona
# Forest Hills Gardens
# Jamaica Hills
# Utopia
# Pomonok
# Astoria Heights
# Hunters Point
# Sunnyside Gardens
# Blissville
# Roxbury
# Middle Village
# Malba
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-561924c1f086> in <module>
#       1 queens_venues = getNearbyVenues(names= queens_data['Neighborhood'],
#       2                                    latitudes= queens_data['Latitude'],
# ----> 3                                    longitudes= queens_data['Longitude'],
#       4                                   )
#
# <ipython-input-29-8c9a08363335> in getNearbyVenues(names, latitudes, longitudes, radius)
#      35                   'Venue Latitude',
#      36                   'Venue Longitude',
# ---> 37                   'Venue Category']
#      38
#      39     return(nearby_venues)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     181             raise ValueError(
#     182                 "Length mismatch: Expected axis has {old} elements, new "
# --> 183                 "values have {new} elements".format(old=old_len, new=new_len)
#     184             )
#     185
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 7 elements

# %%
print(queens_venues.shape)
queens_venues.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-8f470a6544cb> in <module>
# ----> 1 print(queens_venues.shape)
#       2 queens_venues.head()
#
# NameError: name 'queens_venues' is not defined

# %%
manhattan_venues.groupby('Neighborhood').count()
